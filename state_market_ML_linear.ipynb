# %%
import pandas as pd 

tsv_file='state_market_tracker.tsv000'

csv_table=pd.read_table(tsv_file,sep='\t')

csv_table.to_csv('state_market_tracker.csv',index=False)

# %%
state_housing= pd.read_csv('state_market_tracker.csv')

# %%
df = pd.DataFrame(state_housing)
df
# Out:
#       period_begin  period_end  period_duration region_type  region_type_id  \
# 0       2019-10-01  2019-10-31               30       state               4
# 1       2021-07-01  2021-07-31               30       state               4
# 2       2016-08-01  2016-08-31               30       state               4
# 3       2013-04-01  2013-04-30               30       state               4
# 4       2019-12-01  2019-12-31               30       state               4
# ...            ...         ...              ...         ...             ...
# 27073   2012-03-01  2012-03-31               30       state               4
# 27074   2016-07-01  2016-07-31               30       state               4
# 27075   2020-11-01  2020-11-30               30       state               4
# 27076   2021-08-01  2021-08-31               30       state               4
# 27077   2012-11-01  2012-11-30               30       state               4
#
# ...

# %%
df = df.drop(columns = ["region_type", "region_type_id","property_type","is_seasonally_adjusted", "city","price_drops", "price_drops_mom","price_drops_yoy","parent_metro_region", "parent_metro_region_metro_code","months_of_supply", "months_of_supply_mom", "months_of_supply_yoy","last_updated","period_duration", "table_id", "state", "period_begin", "period_end"])
df
# Out:
#               region state_code  property_type_id  median_sale_price  \
# 0           Oklahoma         OK                 4             162200
# 1            Vermont         VT                -1             317900
# 2      New Hampshire         NH                 3             200100
# 3        Mississippi         MS                -1             129500
# 4           Missouri         MO                 3             152000
# ...              ...        ...               ...                ...
# 27073       Nebraska         NE                -1             133000
# 27074          Idaho         ID                13             178400
# 27075       Virginia         VA                 4             264200
# 27076        Vermont         VT                 6             326800
# 27077       Missouri         MO                -1             112200
#
#        median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# ...

# %%
df = df.dropna()
df
# Out:
#               region state_code  property_type_id  median_sale_price  \
# 0           Oklahoma         OK                 4             162200
# 1            Vermont         VT                -1             317900
# 2      New Hampshire         NH                 3             200100
# 3        Mississippi         MS                -1             129500
# 5         New Mexico         NM                -1             385500
# ...              ...        ...               ...                ...
# 27073       Nebraska         NE                -1             133000
# 27074          Idaho         ID                13             178400
# 27075       Virginia         VA                 4             264200
# 27076        Vermont         VT                 6             326800
# 27077       Missouri         MO                -1             112200
#
#        median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# ...

# %%
def change_state(state):
    if state == "AK":
        return 1
    if state == "AL":
        return 2
    if state == "AR":
        return 3
    if state == "AZ":
        return 4
    if state == "CA":
        return 5
    if state == "CO":
        return 6
    if state == "CT":
        return 7
    if state == "DC":
        return 8
    if state == "DE":
        return 9
    if state == "FL":
        return 10
    if state == "GA":
        return 11
    if state == "HI":
        return 12
    if state == "IA":
        return 13
    if state == "ID":
        return 14
    if state == "IL":
        return 15
    if state == "IN":
        return 16
    if state == "KS":
        return 17
    if state == "KY":
        return 18
    if state == "LA":
        return 19
    if state == "MA":
        return 20
    if state == "MD":
        return 21
    if state == "ME":
        return 22
    if state == "MI":
        return 23
    if state == "MN":
        return 24
    if state == "MO":
        return 25
    if state == "MS":
        return 26
    if state == "MT":
        return 27
    if state == "NC":
        return 28
    if state == "ND":
        return 29
    if state == "NE":
        return 30
    if state == "NH":
        return 31
    if state == "NJ":
        return 32
    if state == "NM":
        return 33
    if state == "NV":
        return 34
    if state == "NY":
        return 35
    if state == "OH":
        return 36
    if state == "OK":
        return 37
    if state == "OR":
        return 38
    if state == "PA":
        return 39
    if state == "RI":
        return 40
    if state == "SC":
        return 41
    if state == "SD":
        return 42
    if state == "TN":
        return 43
    if state == "TX":
        return 44
    if state == "UT":
        return 45
    if state == "VA":
        return 46
    if state == "VT":
        return 47
    if state == "WA":
        return 48
    if state == "WI":
        return 49
    if state == "WV":
        return 50
    if state == "WY":
        return 51

df['state_code']=df['state_code'].apply(change_state)
df
# Out:
# /Users/jayanaalves/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               region  state_code  property_type_id  median_sale_price  \
# 0           Oklahoma          37                 4             162200
# 1            Vermont          47                -1             317900
# 2      New Hampshire          31                 3             200100
# 3        Mississippi          26                -1             129500
# 5         New Mexico          33                -1             385500
# ...              ...         ...               ...                ...
# 27073       Nebraska          30                -1             133000
# ...

# %%
df = df.drop(columns = "region")
df
# Out:
#        state_code  property_type_id  median_sale_price  median_sale_price_mom  \
# 0              37                 4             162200              -0.164611
# 1              47                -1             317900              -0.027286
# 2              31                 3             200100               0.011560
# 3              26                -1             129500               0.057733
# 5              33                -1             385500              -0.025947
# ...           ...               ...                ...                    ...
# 27073          30                -1             133000               0.046958
# 27074          14                13             178400              -0.002548
# 27075          46                 4             264200              -0.075868
# 27076          47                 6             326800              -0.000862
# 27077          25                -1             112200              -0.013489
#
# ...

# %%
#df['target_yoy'].sample(20)

# %%
#delete
#df['target_yoy']=df['target_yoy'].apply(change_target)
#df

# %%
#df.info

# %%
# split data into 
X = df.drop(columns = "sold_above_list_yoy")

y = df["sold_above_list_yoy"]

# %%
df = df.dropna()
df
# Out:
#        state_code  property_type_id  median_sale_price  median_sale_price_mom  \
# 0              37                 4             162200              -0.164611
# 1              47                -1             317900              -0.027286
# 2              31                 3             200100               0.011560
# 3              26                -1             129500               0.057733
# 5              33                -1             385500              -0.025947
# ...           ...               ...                ...                    ...
# 27073          30                -1             133000               0.046958
# 27074          14                13             178400              -0.002548
# 27075          46                 4             264200              -0.075868
# 27076          47                 6             326800              -0.000862
# 27077          25                -1             112200              -0.013489
#
# ...

# %%
# check balance of target value. need to oversample?
y.value_counts()
# Out:
#  0.000000    308
#  0.142857     29
#  0.166667     28
# -0.200000     27
#  0.083333     27
#             ...
# -0.003467      1
#  0.045149      1
#  0.043115      1
#  0.045287      1
#  0.008307      1
# Name: sold_above_list_yoy, Length: 23627, dtype: int64

# %%
#df.isnull().sum()

# %%
#df = df.reset_index()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
model_lr = LinearRegression()
model_lr
# Out:
# LinearRegression()

# %%
model_lr.fit(X_train, y_train)
lr_training_score = model_lr.score(X_train, y_train)
lr_testing_score = model_lr.score(X_test, y_test)

# %%
lr_training_score
# Out:
# 0.6028968640580643

# %%
lr_testing_score
# Out:
# 0.5765152894965597

# %%
y_pred_lr = model_lr.predict(X_train)

# %%
lr.score(X_train, y_train)
# Out:
# 0.6097370347286855
