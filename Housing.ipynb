# %%
import pandas as pd 
# import time

# StatrtTime = time.time()
 
tsv_file='zip_code_market_tracker.tsv000'
 
# readinag given tsv file
csv_table=pd.read_table(tsv_file,sep='\t')
 
# converting tsv file into csv
csv_table.to_csv('zip_code_market_tracker.csv',index=False)
 
# executionTime = (time.time() - startTime)
# print('Execution time in seconds: ' + str(executionTime))

# %%
housing= pd.read_csv('zip_code_market_tracker.csv')

# %%
df = pd.DataFrame(housing)

# %%
df.columns
# Out:
# Index(['period_begin', 'period_end', 'period_duration', 'region_type',
#        'region_type_id', 'table_id', 'is_seasonally_adjusted', 'region',
#        'city', 'state', 'state_code', 'property_type', 'property_type_id',
#        'median_sale_price', 'median_sale_price_mom', 'median_sale_price_yoy',
#        'median_list_price', 'median_list_price_mom', 'median_list_price_yoy',
#        'median_ppsf', 'median_ppsf_mom', 'median_ppsf_yoy', 'median_list_ppsf',
#        'median_list_ppsf_mom', 'median_list_ppsf_yoy', 'homes_sold',
#        'homes_sold_mom', 'homes_sold_yoy', 'pending_sales',
#        'pending_sales_mom', 'pending_sales_yoy', 'new_listings',
#        'new_listings_mom', 'new_listings_yoy', 'inventory', 'inventory_mom',
#        'inventory_yoy', 'months_of_supply', 'months_of_supply_mom',
#        'months_of_supply_yoy', 'median_dom', 'median_dom_mom',
#        'median_dom_yoy', 'avg_sale_to_list', 'avg_sale_to_list_mom',
# ...

# %%
df
# Out:
#         period_begin  period_end  period_duration region_type  region_type_id  \
# 0         2017-07-01  2017-09-30               90    zip code               2
# 1         2019-06-01  2019-08-31               90    zip code               2
# 2         2016-05-01  2016-07-31               90    zip code               2
# 3         2013-03-01  2013-05-31               90    zip code               2
# 4         2014-10-01  2014-12-31               90    zip code               2
# ...              ...         ...              ...         ...             ...
# 5310667   2018-03-01  2018-05-31               90    zip code               2
# 5310668   2020-05-01  2020-07-31               90    zip code               2
# 5310669   2014-12-01  2015-02-28               90    zip code               2
# 5310670   2016-03-01  2016-05-31               90    zip code               2
# 5310671   2019-05-01  2019-07-31               90    zip code               2
#
# ...

# %%
df = df.drop(columns = ["region_type", "region_type_id","property_type","is_seasonally_adjusted", "city","price_drops", "price_drops_mom","price_drops_yoy","parent_metro_region", "parent_metro_region_metro_code","months_of_supply", "months_of_supply_mom", "months_of_supply_yoy","last_updated","period_duration", "table_id", "state"])
df
# Out:
#         period_begin  period_end           region state_code  \
# 0         2017-07-01  2017-09-30  Zip Code: 60201         IL
# 1         2019-06-01  2019-08-31  Zip Code: 22310         VA
# 2         2016-05-01  2016-07-31  Zip Code: 48208         MI
# 3         2013-03-01  2013-05-31  Zip Code: 20132         VA
# 4         2014-10-01  2014-12-31  Zip Code: 35758         AL
# ...              ...         ...              ...        ...
# 5310667   2018-03-01  2018-05-31  Zip Code: 95687         CA
# 5310668   2020-05-01  2020-07-31  Zip Code: 55987         MN
# 5310669   2014-12-01  2015-02-28  Zip Code: 60453         IL
# 5310670   2016-03-01  2016-05-31  Zip Code: 33168         FL
# 5310671   2019-05-01  2019-07-31  Zip Code: 63110         MO
#
#          property_type_id  median_sale_price  median_sale_price_mom  \
# 0                      13           434000.0               0.125811
# 1                      -1           489950.0               0.010206
# ...

# %%
pd.set_option('max_columns', None)

# %%
df
# Out:
#         period_begin  period_end           region state_code  \
# 0         2017-07-01  2017-09-30  Zip Code: 60201         IL
# 1         2019-06-01  2019-08-31  Zip Code: 22310         VA
# 2         2016-05-01  2016-07-31  Zip Code: 48208         MI
# 3         2013-03-01  2013-05-31  Zip Code: 20132         VA
# 4         2014-10-01  2014-12-31  Zip Code: 35758         AL
# ...              ...         ...              ...        ...
# 5310667   2018-03-01  2018-05-31  Zip Code: 95687         CA
# 5310668   2020-05-01  2020-07-31  Zip Code: 55987         MN
# 5310669   2014-12-01  2015-02-28  Zip Code: 60453         IL
# 5310670   2016-03-01  2016-05-31  Zip Code: 33168         FL
# 5310671   2019-05-01  2019-07-31  Zip Code: 63110         MO
#
#          property_type_id  median_sale_price  median_sale_price_mom  \
# 0                      13           434000.0               0.125811
# 1                      -1           489950.0               0.010206
# ...

# %%
df = df.dropna()
df
# Out:
#         period_begin  period_end           region state_code  \
# 0         2017-07-01  2017-09-30  Zip Code: 60201         IL
# 1         2019-06-01  2019-08-31  Zip Code: 22310         VA
# 3         2013-03-01  2013-05-31  Zip Code: 20132         VA
# 4         2014-10-01  2014-12-31  Zip Code: 35758         AL
# 6         2019-04-01  2019-06-30  Zip Code: 85207         AZ
# ...              ...         ...              ...        ...
# 5310660   2016-11-01  2017-01-31  Zip Code: 92102         CA
# 5310662   2012-05-01  2012-07-31  Zip Code: 23112         VA
# 5310664   2021-09-01  2021-11-30  Zip Code: 91362         CA
# 5310668   2020-05-01  2020-07-31  Zip Code: 55987         MN
# 5310669   2014-12-01  2015-02-28  Zip Code: 60453         IL
#
#          property_type_id  median_sale_price  median_sale_price_mom  \
# 0                      13           434000.0               0.125811
# 1                      -1           489950.0               0.010206
# ...

# %% [markdown]
# What Else should we drop? State Code, table_id, Important?

# %%
def change_state(state):
    if state == "AK":
        return 1
    if state == "AL":
        return 2
    if state == "AR":
        return 3
    if state == "AZ":
        return 4
    if state == "CA":
        return 5
    if state == "CO":
        return 6
    if state == "CT":
        return 7
    if state == "DC":
        return 8
    if state == "DE":
        return 9
    if state == "FL":
        return 10
    if state == "GA":
        return 11
    if state == "HI":
        return 12
    if state == "IA":
        return 13
    if state == "ID":
        return 14
    if state == "IL":
        return 15
    if state == "IN":
        return 16
    if state == "KS":
        return 17
    if state == "KY":
        return 18
    if state == "LA":
        return 19
    if state == "MA":
        return 20
    if state == "MD":
        return 21
    if state == "ME":
        return 22
    if state == "MI":
        return 23
    if state == "MN":
        return 24
    if state == "MO":
        return 25
    if state == "MS":
        return 26
    if state == "MT":
        return 27
    if state == "NC":
        return 28
    if state == "ND":
        return 29
    if state == "NE":
        return 30
    if state == "NH":
        return 31
    if state == "NJ":
        return 32
    if state == "NM":
        return 33
    if state == "NV":
        return 34
    if state == "NY":
        return 35
    if state == "OH":
        return 36
    if state == "OK":
        return 37
    if state == "OR":
        return 38
    if state == "PA":
        return 39
    if state == "RI":
        return 40
    if state == "SC":
        return 41
    if state == "SD":
        return 42
    if state == "TN":
        return 43
    if state == "TX":
        return 44
    if state == "UT":
        return 45
    if state == "VA":
        return 46
    if state == "VT":
        return 47
    if state == "WA":
        return 48
    if state == "WI":
        return 49
    if state == "WV":
        return 50
    if state == "WY":
        return 51

df['state_code']=df['state_code'].apply(change_state)
df
# Out:
# C:\Users\Wastina Belayneh\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         period_begin  period_end           region  state_code  \
# 0         2017-07-01  2017-09-30  Zip Code: 60201          15
# 1         2019-06-01  2019-08-31  Zip Code: 22310          46
# 3         2013-03-01  2013-05-31  Zip Code: 20132          46
# 4         2014-10-01  2014-12-31  Zip Code: 35758           2
# 6         2019-04-01  2019-06-30  Zip Code: 85207           4
# ...              ...         ...              ...         ...
# 5310660   2016-11-01  2017-01-31  Zip Code: 92102           5
# 5310662   2012-05-01  2012-07-31  Zip Code: 23112          46
# ...

# %%
df = df.drop(columns = ["period_begin","period_end"])
df.head()
# Out:
#             region  state_code  property_type_id  median_sale_price  \
# 0  Zip Code: 60201          15                13           434000.0
# 1  Zip Code: 22310          46                -1           489950.0
# 3  Zip Code: 20132          46                -1           450000.0
# 4  Zip Code: 35758           2                13           125000.0
# 6  Zip Code: 85207           4                 6           375000.0
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0               0.125811               0.166667           339000.0
# 1               0.010206               0.062568           489000.0
# 3              -0.010989               0.046755           475000.0
# 4               0.000000               0.272601           124900.0
# 6               0.030928              -0.079755           383750.0
#
#    median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  \
# ...

# %%
df['region'] = df.region.str.replace('Zip Code:?' , '')
df.head()
# Out:
# C:\Users\Wastina Belayneh\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
#    region  state_code  property_type_id  median_sale_price  \
# 0   60201          15                13           434000.0
# 1   22310          46                -1           489950.0
# 3   20132          46                -1           450000.0
# 4   35758           2                13           125000.0
# 6   85207           4                 6           375000.0
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0               0.125811               0.166667           339000.0
# 1               0.010206               0.062568           489000.0
# 3              -0.010989               0.046755           475000.0
# 4               0.000000               0.272601           124900.0
# ...

# %%
df["region"]=df["region"].astype(int)
df.dtypes
# Out:
# region                           int32
# state_code                       int64
# property_type_id                 int64
# median_sale_price              float64
# median_sale_price_mom          float64
# median_sale_price_yoy          float64
# median_list_price              float64
# median_list_price_mom          float64
# median_list_price_yoy          float64
# median_ppsf                    float64
# median_ppsf_mom                float64
# median_ppsf_yoy                float64
# median_list_ppsf               float64
# median_list_ppsf_mom           float64
# median_list_ppsf_yoy           float64
# homes_sold                     float64
# homes_sold_mom                 float64
# homes_sold_yoy                 float64
# pending_sales                  float64
# pending_sales_mom              float64
# pending_sales_yoy              float64
# new_listings                   float64
# new_listings_mom               float64
# new_listings_yoy               float64
# ...

# %%
df.head(10)
# Out:
#     region  state_code  property_type_id  median_sale_price  \
# 0    60201          15                13           434000.0
# 1    22310          46                -1           489950.0
# 3    20132          46                -1           450000.0
# 4    35758           2                13           125000.0
# 6    85207           4                 6           375000.0
# 7    85742           4                -1           188600.0
# 10   21218          21                 3           133000.0
# 11   37211          43                 6           390500.0
# 12   77336          44                 6           185950.0
# 13    8243          32                13           824000.0
#
#     median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0                0.125811               0.166667           339000.0
# 1                0.010206               0.062568           489000.0
# 3               -0.010989               0.046755           475000.0
# ...

# %%
df['target'] = df['sold_above_list'].copy()

# %%
# change value of sold above list depending on value
df.loc[df.sold_above_list>0,'target']='Above List'

df.loc[df.sold_above_list<0,'target']='Below List'

df.loc[df.sold_above_list==0,'target']='At List'

# %%
df.head(10)
# Out:
#     region  state_code  property_type_id  median_sale_price  \
# 0    60201          15                13           434000.0
# 1    22310          46                -1           489950.0
# 3    20132          46                -1           450000.0
# 4    35758           2                13           125000.0
# 6    85207           4                 6           375000.0
# 7    85742           4                -1           188600.0
# 10   21218          21                 3           133000.0
# 11   37211          43                 6           390500.0
# 12   77336          44                 6           185950.0
# 13    8243          32                13           824000.0
#
#     median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0                0.125811               0.166667           339000.0
# 1                0.010206               0.062568           489000.0
# 3               -0.010989               0.046755           475000.0
# ...

# %%
def change_target(target):
    if target == "Above List":
        return 2
    if target == "Below List":
        return 1
    if target == "At List":
        return 0

# %%
df['target']=df['target'].apply(change_target)
df.head(10)
# Out:
#     region  state_code  property_type_id  median_sale_price  \
# 0    60201          15                13           434000.0
# 1    22310          46                -1           489950.0
# 3    20132          46                -1           450000.0
# 4    35758           2                13           125000.0
# 6    85207           4                 6           375000.0
# 7    85742           4                -1           188600.0
# 10   21218          21                 3           133000.0
# 11   37211          43                 6           390500.0
# 12   77336          44                 6           185950.0
# 13    8243          32                13           824000.0
#
#     median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0                0.125811               0.166667           339000.0
# 1                0.010206               0.062568           489000.0
# 3               -0.010989               0.046755           475000.0
# ...
